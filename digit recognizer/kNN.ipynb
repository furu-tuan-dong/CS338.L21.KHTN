# %%
# Euclidian
# !python3 tune.py --dist_func 'euclid'
# Out:
# Namespace(batch_size=2048, dist_func='euclid', num_folds=3, training_csv='./data/train.csv')
# Load Training CSV time: 5.622790813446045
# [INFO] Setting k = 1
# [INFO] Fold 0 is running...
# 100%|█████████████████████████████████████████████| 7/7 [00:32<00:00,  4.66s/it]
# [INFO] Fold 1 is running...
# 100%|█████████████████████████████████████████████| 7/7 [00:42<00:00,  6.00s/it]
# [INFO] Fold 2 is running...
# 100%|█████████████████████████████████████████████| 7/7 [00:44<00:00,  6.34s/it]
# [INFO] Mean score: 0.9644047619047619
# [INFO] Setting k = 2
# [INFO] Fold 0 is running...
# 100%|█████████████████████████████████████████████| 7/7 [00:40<00:00,  5.76s/it]
# [INFO] Fold 1 is running...
# 100%|█████████████████████████████████████████████| 7/7 [00:34<00:00,  4.88s/it]
# [INFO] Fold 2 is running...
# 100%|█████████████████████████████████████████████| 7/7 [00:40<00:00,  5.73s/it]
# [INFO] Mean score: 0.9573095238095238
# [INFO] Setting k = 3
# [INFO] Fold 0 is running...
# ...

# %%
# Cosine
# !python tune.py --dist_func 'cosine'
# Out:
# Namespace(batch_size=2048, dist_func='cosine', num_folds=3, training_csv='./data/train.csv')
# Load Training CSV time: 6.116031885147095
# [INFO] Setting k = 1
# [INFO] Fold 0 is running...
# 100%|█████████████████████████████████████████████| 7/7 [00:29<00:00,  4.25s/it]
# [INFO] Fold 1 is running...
# 100%|█████████████████████████████████████████████| 7/7 [00:38<00:00,  5.57s/it]
# [INFO] Fold 2 is running...
# 100%|█████████████████████████████████████████████| 7/7 [00:47<00:00,  6.72s/it]
# [INFO] Mean score: 0.9693333333333335
# [INFO] Setting k = 2
# [INFO] Fold 0 is running...
# 100%|█████████████████████████████████████████████| 7/7 [00:42<00:00,  6.13s/it]
# [INFO] Fold 1 is running...
# 100%|█████████████████████████████████████████████| 7/7 [00:44<00:00,  6.42s/it]
# [INFO] Fold 2 is running...
# 100%|█████████████████████████████████████████████| 7/7 [00:54<00:00,  7.73s/it]
# [INFO] Mean score: 0.9661190476190477
# [INFO] Setting k = 3
# [INFO] Fold 0 is running...
# ...
